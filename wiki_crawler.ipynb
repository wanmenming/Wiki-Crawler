# %% [markdown]
# # set Threshold here for key word variation

# %%
global Threshold
Threshold = 0.3

# %%
import time
import re
import urllib.request
import urllib
from collections import deque
import requests 
import json
from itertools import product
from nltk.corpus import wordnet
from itertools import product
#import pyenchant
#This will not run on online IDE 
from bs4 import BeautifulSoup 
""" 
def write_to_file(filename,content_list):
    f= open(filename,"a+",encoding="utf-8")
    for line in content_list:
        if "\r\n" not in line:
            f.write(line+"\r\n")
        else:
            f.write(line)
    f.close()
    
    def write_to_file(filename,content_list,flag):
    f= open(filename,"a+",encoding="utf-8")
    if flag == True:
        f.write(line+"\r\n")
    else:
        f.write(line)      
    for line in content_list:
        if "\r\n" not in line:
            f.write(line+"\r\n")
        else:
            f.write(line)
    f.close()

"""
def write_to_file(filename,content_list,flag):
    
    f= open(filename,"a+",encoding="utf-8")
    if flag == True:
        url = content_list.popleft()
        #print(url)
        f.write(json.dumps(url))
        #f.write('\n'.join('%s %s' % x for x in content_list))
        """
        for line in content_list:
            if "\r\n" not in line:
                f.write(line)
                f.write("\r\n")
            else:
                f.write(line)
        """    
    else:
        if "\r\n" not in content_list:
            f.write(content_list+"\r\n")
        else:
            f.write(content_list) 
    f.close()


#write_to_file("timezone.txt","This is line content\r\n")

# %%
"""
scrap all the links on the current page, 
extract anchor text into global variable -- "anchor_text"
return the url_set for the next depth
by filterring admin page, 
non-English page, avoiding outside link, 
ignoring navigations and marginal/side links; 
avoiding main Wikipedia page,disambiguation
"""

def get_current_pageurl_set(url,dom,en_keyword):
    #url_set=set() 
    url_set = deque()
    # ignore navigations and marginal/side links; ignore Non‐English articles
    inner_contents = dom.find("div", {"id":"mw-content-text","lang":"en"})
    #print(inner_contents)
    try:
        if len(inner_contents) > 0:
            #ignore external links
            external_links = inner_contents.findAll("a",{"class":"external"})
            for match in external_links:
                match.decompose()
            #links = inner_contents.findAll("a", href=True)
            #find_all <a href=/wiki..., avoid outside link
            links = inner_contents.findAll('a', attrs={'href': re.compile("^/wiki")})
            #linkre = re.compile('href=\"https://en.wikipedia.org/wiki(.+?)\"')
            #linkre.findall(inner_contents):
            #print(links)
            for link in links:
                wiki_url = link["href"].strip()
                archor_text = link.text
                # just Follow the links with the prefix /wiki, ignore # in current page,
                #linkre_wiki = re.compile("/wiki(.+?)").match(link_url).group(0)
                #print("linkre_wiki pattern match: " + wiki_url + "\r\n")
                #if linkre_wiki != None:
                #print("get inner url from /wiki/... pattern <--- " + wiki_url)
                message = "get inner url from /wiki/... pattern <--- " + wiki_url
                write_to_file('execute.log',message,False)
                ignore_filter = False
                # ignore administrative links, main Wikipedia page,disambiguation
                ignore_pattern_list = ["\D+:\D+","/wiki/Main_Page$","disambiguation"]
                for ignor in ignore_pattern_list:
                    try:
                        linkre_ignor = re.compile(ignor).search(wiki_url).group()
                        if linkre_ignor != None:
                            ignore_filter = True
                            filter_pattern = ignor
                            break
                    except AttributeError:
                        #print("Don't match pattern-- >"+ignor+ "\r\n")
                        message = "Don't match pattern-- >"+ignor+ "\r\n"
                        write_to_file('execute.log',message,False)
                        continue
                if ignore_filter == True:
                    #print("Ignore the current url --->"+wiki_url + ". Pattern---> "+filter_pattern+ "\r\n")
                    f= open("ignore.log","a+",encoding="utf-8")
                    f.write("Ignore the current url:"+wiki_url+". Pattern: "+filter_pattern + "\r\n")
                    f.close()
                else:
                    url_set.append(wiki_url)
                    if en_keyword == True:
                        anchor_text.append(archor_text)
                    #print('Add URL to the queue --->  ' + wiki_url + "\r\n")
                    message = 'Add URL to the queue --->  ' + wiki_url + "\r\n"
                    write_to_file('execute.log',message,False)
    except TypeError:
        message = url+" can't find the content block \r\n" + "pattern is: {id:mw-content-text,lang:en}\r\n" 
        log_name = "lostContentBlock.txt"
        write_to_file(log_name,message,False)
         
    return url_set

# %%
"""
Main body of our crawller
start from seed,
if enable check_keyword, 
we will also estimate the correlation of the currrent anchor text with key word
For polite crawlling, set timesleep = 10 seconds
'frontier_queue' used for the list of url we will crawl one by one
'visited' handled all the url we have visited
'url_depth' used for store the url and its depth information
Every request, ignore image, no-english-html,non-‐textual media, table
find all the canonical link, put them in visited
"""
def Walk_wiki(seed,check_keyword):
    """
    crawlling from the seed, until 6 depth or 1000 url
    """
    #my frontier
    frontier_queue = deque()
    depth = 1;
    
    frontier_queue.append({depth:seed})
    cnt = 1
    
    #avoid crwalling duplicated url
    visited = set();
   
    
    # restore pairs of depth and url 
    url_depth = deque();
    
    #visited = set(visited_path)
    while frontier_queue:
        
        url_depth_pair = frontier_queue.popleft()  # get url from the frontier top 
        depth,url = list(url_depth_pair.items())[0]
        
        if int(depth) > 6:
            print("We are already at the 6th depth. Stop crawlling now! \r\n")
            break
        if int(cnt) > 1000:
            print("We are already get 1000 urls. Stop crawlling now! \r\n")
            break
        
        if url not in visited:
            print('All ready got the: ' + str(cnt) + ' URL.  Currently crawling at:  <---  ' + url)
            message = "All ready got the: " + str(cnt) + "URL.  Currently crawling at:  <--- "  + url
            write_to_file('execute.log',message,False)
            
            try:
                #headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 Safari/537.36'}
                headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 Safari/537.36',
'Accept':'text/html;q=0.9,/;q=0.8',
'Accept-Charset':'ISO-8859-1,utf-8;q=0.7,*;q=0.3',
'Accept-Encoding':'gzip, deflate, br',
'Accept-Language':'en-US,en',
'Connection':'close',
'Referer':'https://www.google.com/'}
                #polite restriction
                t0 = time.time()
                r = requests.get(url,headers=headers, timeout=10)
                #response_delay = 10*(time.time() - t0)
                response_delay = 5
                respose_message = str(r.status_code) +'\r\n Our crawller is politely Waiting for<---  ' + str(response_delay) +"seconds. Current URL is: "+ url+ "\r\n"
                #print(respose_message)
                message = respose_message
                write_to_file('execute.log',message,False)
                time.sleep(response_delay)
                
                if "blocked" in r.text:
                    #print (str(cnt) + url + " Request Error: we've been blocked\r\n")
                    message = str(cnt) + url + " Request Error: we've been blocked\r\n"
                    write_to_file('execute.log',message,False)
                    f = open("blocked.log","a+",encoding="utf-8")
                    f.write(str(cnt) + url + " Request Error: we've been blocked\r\n")
                    f.close()
                else:
                    content_type = r.headers.get('content-type')
                    content_language = r.headers.get('content-language')
                    # ignore image, no-english-html,non-‐textual media.
                    if 'html' in content_type and 'en' in content_language:
                        #print("Request: "+ str(cnt) +"URL--> "+url+" ---> content-type: "+ content_type + " content-language: " + content_language +"\r\n")
                        message = "Request: "+ str(cnt) +"URL--> "+url+" ---> content-type: "+ content_type + " content-language: " + content_language +"\r\n"
                        write_to_file('execute.log',message,False)
                        #soup = BeautifulSoup(r.content, 'html5lib')
                        soup = BeautifulSoup(r.text, "html.parser")
                        
                        #ignore table
                        try:
                            soup.table.decompose();

                            # get all the url we desired in current page
                            if(check_keyword == True):
                                next_depth_url = match_against_keywords(url,soup)
                            else:
                                next_depth_url = get_current_pageurl_set(url,soup,False)
                                
                            #next_depth_url = fetch_url
                            for scrap_url in next_depth_url:
                                next_depth = depth + 1
                                fetch_url = "https://en.wikipedia.org" + scrap_url
                                frontier_queue.append({next_depth:fetch_url})
                            #url_depth |= {(fetch_url,next_depth)}
                        
                        #depth += 1
                            visited |= {url}       # after crawling, put it in visited set
                            url_depth.append({next_depth:url})
                            #test
                            f = open("Frontier.log","a+",encoding="utf-8")
                            f.write(url + " "+ str(depth) + "\n")
                            f.close()
                            #find canonical link and put in the visited set
                            canonical_links = soup.find("link",{"rel":"canonical"})["href"]
                            if (canonical_links != url):
                                visited |= {canonical_links}
                            #visited_dom_name = url +".txt";
                            visited_dom_name = str(cnt) +".txt";
                            cnt += 1
                            #f = open(visited_dom_name,"a+",encoding="utf-8")
                            #f.write(r.content)
                            #f.close()
                            message = str(url) + "\r\n" + r.text
                            #write_to_file(visited_dom_name,r.text,False)
                            write_to_file(visited_dom_name,message,False)
                        except AttributeError:
                            #message = "we didn't get page!!! url-->"+url+". The times:"+ str(cnt) + "\r\n"
                            #print("Didn't get soup. Please check log")
                            message = "Didn't get soup. Please check log"
                            write_to_file('execute.log',message,False)
                            block_message = url + str(soup)
                            write_to_file("souperror.log",block_message,False)
                            """
                            else:
                            message = "we didn't get page!!! url-->"+url+". The times:"+ str(cnt) + "\r\n"
                            print(message)
                            write_to_file("emptypage.log",message,False)
                            """        
                    else:
                        message = "we've been on weird page!!! url-->"+url+". Content-Type:"+ content_type + " Content-Language: "+ content_language + "\r\n"
                        #print(message)
                        #message = "Didn't get soup. Please check log"
                        write_to_file('execute.log',message,False)
                        write_to_file("ignorepage.log",message,False)
                        #f = open("blocked.log","a+")
                        #f.write(url + " Request Error: we've been blocked\r\n")
                        #f.close() 
                        
            except requests.exceptions.RequestException:
                #print("Request Error ---->"+ requests.exceptions.RequestException + "\r\n")
                message = "Request Error ---->"+ requests.exceptions.RequestException + "\r\n"
                write_to_file('execute.log',message,False)
                f = open("RequerstError.log","a+",encoding="utf-8")
                f.write(url + " Request Error "+ requests.exceptions.RequestException + "\r\n")
                f.close()
                continue  
    return url_depth

# %%
"""

"""
def keywords_importance(archor_text,keywords):
    weights = []
    
    #Thanks to @alexis' note from https://stackoverflow.com/questions/30829382/check-the-similarity-between-two-words-with-nltk-with-python
    for word1 in archor_text:
        for word2 in keywords:
            wordFromList1 = wordnet.synsets(word1)
            wordFromList2 = wordnet.synsets(word2)
            if wordFromList1 and wordFromList2: 
                s = wordFromList1[0].wup_similarity(wordFromList2[0])
                if s == None:
                    s = 0.0
                pair = {'weight':s,'key_word':word1}
                weights.append(pair)
                #print("SSSSSS")
                #print(s)
    seq = [x['weight'] for x in weights]
    if len(seq) == 0:
        max_weight = 0.0
    else:
        max_weight = max(seq)
    #print("max_weight")
    #print(max_weight)
    #max_weight = (max(weights["weight"]))
    find = False
    for item in weights:
        if item["weight"] == max_weight:
            find_keywords = item["key_word"]
            find = True
            break
    if find == False:
        find_keywords = "green"
    
    return {'weight':max_weight,'key_word':find_keywords}

# %%
# for keywords set, avoid duplicate
def remove_duplicate(duplicate): # thanks to https://www.geeksforgeeks.org/python-remove-duplicates-list/
    final_list = [] 
    for num in duplicate: 
        if num not in final_list: 
            final_list.append(num) 
    return final_list

# %%
"""
Return the url match against out keywords
get all the url, filtered by get_current_pageurl_set() and their anchor text
for each url and its anchor text: 
compared with keywords set and estimate the correlation between them
set Threshold as 0.7
if correlation > 0.7, we think they are highly correlated, 
we will put it in frontier waiting for visiting
"""
def match_against_keywords(url,soup):
    final_url_list = deque()
    
    raw_url = get_current_pageurl_set(url,soup,True)
    keywords_set = remove_duplicate(key_words_list)
    message = "Now search keywords is:"
    print("Now search keywords is:")            
    for keyword_item in keywords_set:
        print(keyword_item)
        write_to_file('execute.log',message,False)
    while anchor_text:
        current_text = anchor_text.popleft()
        current_url = raw_url.popleft()
        # find target url with keywords pattern
        #keywords_set = remove_duplicate(key_words_list)
        key_words_pattern = ""
        
        for word in keywords_set:
            if current_text.lower().find(word) != -1 and current_url.lower().find(word):
                text_list = current_text.split()
                data = keywords_importance(text_list,key_words_list)
                words_weight = data["weight"]
                relative_keyword = data["key_word"]
                #print("weight!!!")
                #words_weight,relative_keyword = keywords_importance(text_list,key_words_list)
                #Threshold = 0.7
                if words_weight == None:
                    words_weight_float = 0.0
                else:
                    words_weight_float = float(words_weight)
                if words_weight_float > Threshold:
                    print("similar word from anchor text:")
                    print(relative_keyword)
                    print("weight:")
                    print(words_weight)
                    final_url_list.append(current_url)
                    key_words_list.append(relative_keyword)
                    message = "similar word from anchor text:"+ relative_keyword + "weight:" + str(words_weight) + "\r\n" + "Add URL to the queue --->  " + current_url + "\r\n"
                    print('Add URL to the queue --->  ' + current_url + "\r\n")
                    write_to_file('execute.log',message,False)
    return final_url_list

# %% [markdown]
# # Entrance of problem 3

# %%
#https://en.wikipedia.org/wiki/Carbon_footprint
def problem3():
    URL = input("Please type the seed URL: ");
    key_words = input("Please type the keywords list, seperated by comma: ");
    print(URL)
    #handel the keyword variation
    global key_words_list
    
    # extract the achor text here, if it match against keywords 
    #(compared by their correlation), anchor_text would be added to keywords sets
    global anchor_text
    
    key_words_list = key_words.split()
    anchor_text = deque()   
    url_set = Walk_wiki(URL,True)
    
    write_to_file("crawlerlistwithkeywords.txt",url_set,True)
    
problem3()
# Out:
# Please type the seed URL: https://en.wikipedia.org/wiki/Carbon_footprint
# Please type the keywords list, seperated by comma: green
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     729             try:
# --> 730                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     731             except Exception:
#
# ~\Anaconda3\lib\site-packages\jupyter_client\session.py in recv(self, socket, mode, content, copy)
#     795         try:
# --> 796             msg_list = socket.recv_multipart(mode, copy=copy)
#     797         except zmq.ZMQError as e:
#
# ~\Anaconda3\lib\site-packages\zmq\sugar\socket.py in recv_multipart(self, flags, copy, track)
#     394         """
# --> 395         parts = [self.recv(flags, copy=copy, track=track)]
#     396         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv (zmq\backend\cython\socket.c:7683)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv (zmq\backend\cython\socket.c:7460)()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy (zmq\backend\cython\socket.c:2344)()
#
# ~\Anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc (zmq\backend\cython\socket.c:9621)()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-e89123335859> in <module>()
#      18     write_to_file("crawlerlistwithkeywords.txt",url_set,True)
#      19
# ---> 20 problem3()
#
# <ipython-input-8-e89123335859> in problem3()
#       3 def problem3():
#       4     URL = input("Please type the seed URL: ");
# ----> 5     key_words = input("Please type the keywords list, seperated by comma: ");
#       6     print(URL)
#       7     #handel the keyword variation
#
# ~\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     703             self._parent_ident,
#     704             self._parent_header,
# --> 705             password=False,
#     706         )
#     707
#
# ~\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     733             except KeyboardInterrupt:
#     734                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 735                 raise KeyboardInterrupt
#     736             else:
#     737                 break
#
# KeyboardInterrupt:

# %% [markdown]
# # Entrance of problem 1

# %%
#%connect_info
#https://en.wikipedia.org/wiki/Time_zone

#%qtconsole
def problem1():
    URL = input("Please type the seed URL");
    print(URL)   
    url_set = Walk_wiki(URL,False)
    write_to_file("crawlerlist.txt",url_set,True)
    
problem1()
# Out:
# Please type the seed URLhttps://en.wikipedia.org/wiki/Electric_car
# https://en.wikipedia.org/wiki/Electric_car
# All ready got the: 1 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Electric_car
# All ready got the: 2 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Electric_vehicle
# All ready got the: 3 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Hybrid_electric_vehicle
# All ready got the: 4 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Fuel_cell_vehicle
# All ready got the: 5 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Tesla_Model_S
# All ready got the: 6 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Tesla_Supercharger
# All ready got the: 7 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Nissan_Leaf
# All ready got the: 8 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Plug-in_electric_vehicle
# All ready got the: 8 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Automobile
# All ready got the: 9 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Electric_motor
# All ready got the: 9 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Electric-vehicle_battery
# All ready got the: 10 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/2000s_energy_crisis
# All ready got the: 11 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Greenhouse_gas_emissions
# All ready got the: 12 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Government_incentives_for_plug-in_electric_vehicles
# All ready got the: 13 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/All-electric_range
# All ready got the: 14 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Internal_combustion_engine
# All ready got the: 15 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Exhaust_gas#Main_motor_vehicle_emissions
# All ready got the: 16 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Air_pollution
# All ready got the: 17 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Charging_station
# All ready got the: 18 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/United_States_Environmental_Protection_Agency
# All ready got the: 19 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/NASA
# All ready got the: 20 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Lunar_Roving_Vehicle
# All ready got the: 21 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Automobiles
# All ready got the: 22 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Low-speed_vehicle
# All ready got the: 22 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Neighborhood_electric_vehicle
# All ready got the: 23 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Motorised_quadricycle
# All ready got the: 24 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Microcar
# All ready got the: 25 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/City_car
# All ready got the: 26 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Solar_panel
# All ready got the: 27 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Solar_car
# All ready got the: 28 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Hybrid_car
# All ready got the: 29 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Battery_electric_vehicle
# All ready got the: 30 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Battery_electric_vehicles
# All ready got the: 31 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Plug-in_hybrid_electric_vehicles
# All ready got the: 32 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/History_of_the_electric_vehicle
# All ready got the: 33 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Thomas_Parker_(inventor)
# All ready got the: 34 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/General_Motors_EV1
# All ready got the: 35 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/California_Air_Resources_Board
# All ready got the: 36 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Nickel%E2%80%93metal_hydride_battery
# All ready got the: 37 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Tesla_Roadster_(2008)
# All ready got the: 38 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Ford_Model_T
# All ready got the: 39 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/London
# All ready got the: 40 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Andreas_Flocken
# All ready got the: 41 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Electrobat
# All ready got the: 41 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/S.R._Bailey_%26_Co.
# All ready got the: 42 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Starter_(engine)
# All ready got the: 43 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Crank_(mechanism)#20th_Century
# All ready got the: 44 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Land_speed_record
# All ready got the: 45 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/La_Jamais_Contente
# All ready got the: 46 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Camille_Jenatzy
# All ready got the: 47 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Zero-emissions_vehicle
# All ready got the: 47 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Chrysler_TEVan
# All ready got the: 48 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Ford_Ranger_EV
# All ready got the: 49 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/GM_EV1
# All ready got the: 50 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Chevrolet_S10_EV
# All ready got the: 51 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Honda_EV_Plus
# All ready got the: 52 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Nissan_Altra
# All ready got the: 53 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Toyota_RAV4_EV
# All ready got the: 54 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Solectria_Force
# All ready got the: 55 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/California
# All ready got the: 56 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Tesla_Motors
# All ready got the: 57 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Serial_production
# All ready got the: 58 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Lithium-ion_battery
# All ready got the: 59 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Renault%E2%80%93Nissan%E2%80%93Mitsubishi_Alliance
# All ready got the: 60 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/BYD_Auto
# All ready got the: 61 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/BYD_e6
# All ready got the: 62 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Plug-in_electric_vehicle
# All ready got the: 62 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Car_platform
# All ready got the: 63 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Combustion_engines
# All ready got the: 64 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Environmental_aspects_of_the_electric_car
# All ready got the: 65 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Motor_vehicle_emissions
# All ready got the: 66 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Particulate
# All ready got the: 67 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Soot
# All ready got the: 68 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Volatile_organic_compound
# All ready got the: 69 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Hydrocarbon
# All ready got the: 70 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Carbon_monoxide
# All ready got the: 71 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Ozone
# All ready got the: 71 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Lead
# All ready got the: 72 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/NOx
# All ready got the: 73 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Electricity_generation
# All ready got the: 74 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/The_long_tailpipe
# All ready got the: 75 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Emission_intensity
# All ready got the: 76 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Mains_electricity
# All ready got the: 77 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Rimac_Concept_One
# All ready got the: 78 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Power-to-weight_ratio
# All ready got the: 79 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Horsepower
# All ready got the: 80 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Power_(physics)
# All ready got the: 81 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Traction_(engineering)
# All ready got the: 82 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Axle
# All ready got the: 83 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Differential_(mechanics)
# All ready got the: 84 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Transmission_(mechanics)
# All ready got the: 85 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Venturi_Fetish
# All ready got the: 86 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Supercar
# All ready got the: 87 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/DC_motor
# All ready got the: 88 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Manual_transmission
# All ready got the: 89 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Porsche_918_Spyder
# All ready got the: 90 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Electric_car_energy_efficiency
# All ready got the: 91 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Carnot%27s_theorem_(thermodynamics)
# All ready got the: 92 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Gasoline_engine
# All ready got the: 93 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Diesel_engine
# All ready got the: 94 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Electric_motor
# All ready got the: 94 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Regenerative_braking
# All ready got the: 95 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Electric_vehicle_conversion
# All ready got the: 96 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Energy_conversion_efficiency
# All ready got the: 97 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Heat_pump
# All ready got the: 98 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Positive_Temperature_Coefficient
# All ready got the: 99 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Citro%C3%ABn_Berlingo_Electrique
# All ready got the: 100 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Gasoline
# All ready got the: 100 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Solar_power
# All ready got the: 101 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Tesla_Model_X
# All ready got the: 102 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/International_Organization_for_Standardization
# All ready got the: 103 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Plug-in_electric_vehicle_fire_incidents
# All ready got the: 104 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Vehicle_fire
# All ready got the: 105 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Shenzhen
# All ready got the: 106 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Kent,_Washington
# All ready got the: 107 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Merida,_Mexico
# All ready got the: 108 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Murfreesboro,_Tennessee
# All ready got the: 109 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Firefighter
# All ready got the: 110 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Certified_first_responder
# All ready got the: 111 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Chevrolet_Volt
# All ready got the: 112 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Low_rolling_resistance_tires
# All ready got the: 113 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Insurance_Institute_for_Highway_Safety
# All ready got the: 114 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Low-speed_vehicle
# All ready got the: 114 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Uniti_(car)
# All ready got the: 115 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Electric_vehicle_warning_sounds
# All ready got the: 116 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Roadway_noise
# All ready got the: 116 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Visual_impairment
# All ready got the: 117 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Government_of_Japan
# All ready got the: 118 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/U.S._Congress
# All ready got the: 119 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/European_Parliament
# All ready got the: 119 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Plug-in_electric_vehicle
# All ready got the: 119 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Vehicle_Sound_for_Pedestrians
# All ready got the: 120 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Volkswagen
# All ready got the: 121 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/BMW
# All ready got the: 122 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Noise_pollution
# All ready got the: 123 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Automatic_transmission
# All ready got the: 124 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Parking_pawl
# All ready got the: 125 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Hand_brake
# All ready got the: 126 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Engine_braking
# All ready got the: 127 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Lithium-ion_polymer_battery
# All ready got the: 128 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Electric_battery#Solid_state_batteries
# All ready got the: 129 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Nickel_metal_hydride_battery
# All ready got the: 130 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Zinc-air_battery
# All ready got the: 131 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/List_of_electric_cars_currently_available
# All ready got the: 132 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/EPA
# All ready got the: 133 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Model_year
# All ready got the: 134 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Renault_Twizy
# All ready got the: 135 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Roadside_assistance
# All ready got the: 136 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Battery_swapping
# All ready got the: 137 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Tesla_supercharger
# All ready got the: 138 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Tejon,_California
# All ready got the: 139 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/BMW_i3
# All ready got the: 140 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Range-extended_vehicle
# All ready got the: 140 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Rechargeable_battery#Lifespan_and_cycle_stability
# All ready got the: 141 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Salar_de_Uyuni
# All ready got the: 142 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Bolivia
# All ready got the: 143 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Lithium
# All ready got the: 144 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Plug-in_electric_vehicle#Rare-earth_metals_availability_and_supply_security
# All ready got the: 144 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Electric_motor
# All ready got the: 144 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Rare-earth_element
# All ready got the: 145 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Heavy_metal_(chemistry)
# All ready got the: 146 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Neodymium
# All ready got the: 147 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Boron
# All ready got the: 148 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Cobalt
# All ready got the: 149 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Strategic_material
# All ready got the: 149 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Electric_double-layer_capacitor
# All ready got the: 150 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Flywheel_energy_storage
# All ready got the: 151 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/F%C3%A9d%C3%A9ration_Internationale_de_l%27Automobile
# All ready got the: 152 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Formula_One
# All ready got the: 153 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Solar_vehicle
# All ready got the: 154 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Solar_energy
# All ready got the: 155 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Photovoltaic
# All ready got the: 155 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Rio_de_Janeiro
# All ready got the: 156 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Brazil
# All ready got the: 157 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Petrobras
# All ready got the: 158 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Power_grid
# All ready got the: 159 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Fossil_fuel_power_plant
# All ready got the: 160 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Hydroelectricity
# All ready got the: 161 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Nuclear_power
# All ready got the: 162 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Photovoltaic
# All ready got the: 162 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Micro_hydro
# All ready got the: 163 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Wind_power
# All ready got the: 164 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Global_warming
# All ready got the: 165 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Conductive_coupling
# All ready got the: 166 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/SAE_J1772
# All ready got the: 167 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/European_Automobile_Manufacturers_Association
# All ready got the: 168 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/IEC_62196#Plug_types
# All ready got the: 169 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Inductive_charging#Electric_vehicles
# All ready got the: 170 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Delco_Electronics
# All ready got the: 170 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Magne_Charge
# All ready got the: 171 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Vehicle-to-grid
# All ready got the: 172 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Peak_load
# All ready got the: 173 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Off-peak
# All ready got the: 174 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/United_States_energy_independence
# All ready got the: 175 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Developed_countries
# All ready got the: 176 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Emerging_countries
# All ready got the: 177 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Supply_(economics)
# All ready got the: 178 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Energy_security
# All ready got the: 178 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Developing_countries
# All ready got the: 179 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Africa
# All ready got the: 180 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Balance_of_payments
# All ready got the: 181 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/List_of_production_battery_electric_vehicles
# All ready got the: 182 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Plug-in_electric_vehicle
# All ready got the: 182 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/List_of_modern_production_plug-in_electric_vehicles
# All ready got the: 183 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Plug-in_electric_vehicle
# All ready got the: 183 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Mitsubishi_Motors
# All ready got the: 184 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/BMW_i3_REx
# All ready got the: 185 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Renault_Kangoo_Z.E.
# All ready got the: 186 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Renault_Zoe
# All ready got the: 187 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/BAIC_EC-Series
# All ready got the: 188 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Electric_car_use_by_country
# All ready got the: 189 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Plug-in_electric_vehicles_in_the_United_States
# All ready got the: 190 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/New_energy_vehicles_in_China
# All ready got the: 191 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Plug-in_electric_vehicles_in_Japan
# All ready got the: 192 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Plug-in_electric_vehicles_in_Europe
# All ready got the: 193 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Plug-in_electric_vehicles_in_Norway
# All ready got the: 194 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Plug-in_electric_vehicles_in_France
# All ready got the: 195 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Plug-in_electric_vehicles_in_Germany
# All ready got the: 196 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Plug-in_electric_vehicles_in_Canada
# All ready got the: 197 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Plug-in_electric_vehicles_in_the_United_Kingdom
# All ready got the: 198 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Plug-in_electric_vehicles_in_Sweden
# All ready got the: 199 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Plug-in_electric_vehicle
# All ready got the: 199 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Government_incentives_for_plug-in_electric_vehicles#United_States
# All ready got the: 200 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Plug-in_Car_Grant
# All ready got the: 201 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/European_Union_member_states
# All ready got the: 202 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Government_incentives_for_plug-in_electric_vehicles#Europe
# All ready got the: 203 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Plug-in_hybrid_vehicle
# All ready got the: 204 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Alternative_fuel_vehicle
# All ready got the: 205 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Electric_boat
# All ready got the: 206 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Electric_bus
# All ready got the: 207 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Electric_motorcycles_and_scooters
# All ready got the: 208 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Electric_motorsport
# All ready got the: 209 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Plug-in_electric_vehicle
# All ready got the: 209 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Nissan
# All ready got the: 210 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/International_Standard_Book_Number
# All ready got the: 211 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/David_B._Sandalow
# All ready got the: 212 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/The_Brookings_Institution
# All ready got the: 213 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/International_Standard_Serial_Number
# All ready got the: 214 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Digital_object_identifier
# All ready got the: 215 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Forbes
# All ready got the: 216 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Who_Killed_the_Electric_Car%3F
# All ready got the: 217 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Financial_Times
# All ready got the: 218 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Japan_Automobile_Manufacturers_Association
# All ready got the: 219 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/The_New_York_Times
# All ready got the: 219 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/The_Wall_Street_Journal
# All ready got the: 220 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/U.S._Fire_Administration
# All ready got the: 221 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/USA_Today
# All ready got the: 222 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/The_Detroit_News
# All ready got the: 223 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Toyota_Motor_Company
# All ready got the: 224 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/European_Commission
# All ready got the: 225 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Automotive_News
# All ready got the: 226 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/U.S._Department_of_Energy
# All ready got the: 227 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/U._S._Environmental_Protection_Agency
# All ready got the: 228 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/CNET
# All ready got the: 229 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Discover_(magazine)
# All ready got the: 230 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/The_MIT_Press
# All ready got the: 231 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/R._James_Woolsey
# All ready got the: 232 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Chelsea_Sexton
# All ready got the: 233 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Mongabay
# All ready got the: 234 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/African_Development_Bank
# All ready got the: 235 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/International_Energy_Agency
# All ready got the: 236 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Mexico_City
# All ready got the: 237 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Detroit
# All ready got the: 238 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Munich
# All ready got the: 239 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Palo_Alto
# All ready got the: 240 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Argonne_National_Laboratory
# All ready got the: 241 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Office_of_Energy_Efficiency_%26_Renewable_Energy
# All ready got the: 242 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Bloomberg_News
# All ready got the: 242 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/The_Guardian
# All ready got the: 243 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/International_Council_on_Clean_Transportation
# All ready got the: 244 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Pneumatic_motor
# All ready got the: 245 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Compressed_air_car
# All ready got the: 246 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Compressed-air_vehicle
# All ready got the: 247 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Tesla_turbine
# All ready got the: 247 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Electric_motor
# All ready got the: 247 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Electric_locomotive#Battery_locomotive
# All ready got the: 248 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Cater_MetroTrolley
# All ready got the: 249 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Electric_aircraft
# All ready got the: 250 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Electric_bicycle
# All ready got the: 251 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Pedelec
# All ready got the: 252 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Battery_electric_bus
# All ready got the: 253 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Electric_truck
# All ready got the: 254 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Electric_platform_truck
# All ready got the: 255 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Electric_kick_scooter
# All ready got the: 256 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Sentinel_Waggon_Works#The_Gyro_locomotive
# All ready got the: 257 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Hybrid_train
# All ready got the: 258 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Motorized_bicycle
# All ready got the: 259 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Plug-in_electric_vehicle
# All ready got the: 259 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Solar_bus
# All ready got the: 260 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Biofuel
# All ready got the: 261 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Alcohol_fuel
# All ready got the: 262 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Biodiesel
# All ready got the: 263 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Biogas
# All ready got the: 264 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Butanol_fuel
# All ready got the: 265 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Common_ethanol_fuel_mixtures
# All ready got the: 266 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/E85
# All ready got the: 267 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Ethanol_fuel
# All ready got the: 268 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Flexible-fuel_vehicle
# All ready got the: 269 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Methanol_economy
# All ready got the: 270 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Methanol_fuel
# All ready got the: 270 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Wood_gas
# All ready got the: 271 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Hydrogen
# All ready got the: 272 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Hydrogen_economy
# All ready got the: 273 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Hydrogen_vehicle
# All ready got the: 274 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Hydrogen_internal_combustion_engine_vehicle
# All ready got the: 275 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Autogas
# All ready got the: 276 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Liquid_nitrogen_engine
# All ready got the: 277 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Natural_gas_vehicle
# All ready got the: 278 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Propane
# All ready got the: 279 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Steam_car
# All ready got the: 280 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Bi-fuel_vehicle
# All ready got the: 281 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Multifuel
# All ready got the: 282 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/What_Is_the_Electric_Car%3F
# All ready got the: 283 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Revenge_of_the_Electric_Car
# All ready got the: 284 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Wind-powered_vehicle
# All ready got the: 285 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Zero-emissions_vehicle
# All ready got the: 285 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Car_classification
# All ready got the: 286 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Kei_car
# All ready got the: 287 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Subcompact_car
# All ready got the: 287 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Supermini
# All ready got the: 288 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Family_car
# All ready got the: 289 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Compact_car
# All ready got the: 290 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Mid-size_car
# All ready got the: 291 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Full-size_car
# All ready got the: 292 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Custom_car
# All ready got the: 293 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Hot_rod
# All ready got the: 294 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Lead_sled
# All ready got the: 294 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Lowrider
# All ready got the: 295 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Hot_rod#1960s_rise_of_the_street_rod
# All ready got the: 296 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/T-bucket
# All ready got the: 297 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Luxury_vehicle
# All ready got the: 298 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Compact_executive_car
# All ready got the: 299 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Executive_car
# All ready got the: 300 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Personal_luxury_car
# All ready got the: 301 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Minivan
# All ready got the: 302 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Compact_MPV
# All ready got the: 303 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Mini_MPV
# All ready got the: 304 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Sport_utility_vehicle
# All ready got the: 305 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Compact_sport_utility_vehicle
# All ready got the: 306 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Crossover_(automobile)
# All ready got the: 307 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Mini_sport_utility_vehicle
# All ready got the: 308 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Sports_car
# All ready got the: 309 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Grand_tourer
# All ready got the: 310 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Hot_hatch
# All ready got the: 311 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Muscle_car
# All ready got the: 312 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Pony_car
# All ready got the: 313 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Sport_compact
# All ready got the: 314 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Antique_car
# All ready got the: 315 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Classic_car
# All ready got the: 316 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Economy_car
# All ready got the: 317 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Leisure_activity_vehicle
# All ready got the: 318 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Ute_(vehicle)
# All ready got the: 319 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Van
# All ready got the: 320 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Voiturette
# All ready got the: 321 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/2%2B2_(car_body_style)
# All ready got the: 322 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Baquet_(car_body_style)
# All ready got the: 323 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Barchetta
# All ready got the: 324 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Berlinetta
# All ready got the: 324 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Brougham_(car_body)
# All ready got the: 325 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Cabrio_coach
# All ready got the: 326 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Convertible
# All ready got the: 327 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Coup%C3%A9
# All ready got the: 328 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Coupe_de_Ville
# All ready got the: 329 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Coup%C3%A9_utility
# All ready got the: 330 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Fastback
# All ready got the: 331 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Hardtop
# All ready got the: 332 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Hatchback
# All ready got the: 333 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Landaulet_(car)
# All ready got the: 334 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Liftback
# All ready got the: 335 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Limousine
# All ready got the: 336 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Multi-stop_truck
# All ready got the: 337 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Notchback
# All ready got the: 338 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Panel_van
# All ready got the: 339 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Phaeton_body
# All ready got the: 340 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Pickup_truck
# All ready got the: 341 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Quad_coup%C3%A9
# All ready got the: 342 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Roadster_(automobile)
# All ready got the: 343 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Runabout_(car)
# All ready got the: 344 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Sedan_(automobile)
# All ready got the: 345 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Sedan_delivery
# All ready got the: 346 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Shooting-brake
# All ready got the: 347 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Station_wagon
# All ready got the: 348 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Targa_top
# All ready got the: 349 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Torpedo_(car)
# All ready got the: 350 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Touring_car
# All ready got the: 351 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/T-top
# All ready got the: 352 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Vis-%C3%A0-vis_(carriage)
# All ready got the: 353 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Amphibious_vehicle
# All ready got the: 354 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Connected_car
# All ready got the: 355 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Autonomous_car
# All ready got the: 356 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Hearse
# All ready got the: 357 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Gyrocar
# All ready got the: 358 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Roadable_aircraft
# All ready got the: 359 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Taxicab
# All ready got the: 359 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Tow_truck
# All ready got the: 360 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Ground_propulsion
# All ready got the: 361 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Fuel_cell
# All ready got the: 362 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Gasoline_direct_injection
# All ready got the: 363 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Homogeneous_charge_compression_ignition
# All ready got the: 364 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Drive_wheel
# All ready got the: 365 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Front-wheel_drive
# All ready got the: 366 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Automobile_layout#Rear_wheel_drive_layouts
# All ready got the: 367 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Two-wheel_drive
# All ready got the: 368 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Four-wheel_drive
# All ready got the: 369 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Six-wheel_drive
# All ready got the: 370 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Eight-wheel_drive
# All ready got the: 371 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Ten-wheel_drive
# All ready got the: 372 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Twelve-wheel_drive
# All ready got the: 373 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Front-engine,_front-wheel-drive_layout
# All ready got the: 374 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Mid-engine_design
# All ready got the: 375 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Rear-engine_design
# All ready got the: 376 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Front_mid-engine,_front-wheel-drive_layout
# All ready got the: 377 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Rear-engine,_front-wheel-drive_layout
# All ready got the: 378 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Front-engine,_rear-wheel-drive_layout
# All ready got the: 379 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Rear_mid-engine,_rear-wheel-drive_layout
# All ready got the: 380 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Rear-engine,_rear-wheel-drive_layout
# All ready got the: 381 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Front-engine,_four-wheel-drive_layout
# All ready got the: 382 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Mid-engine,_four-wheel-drive_layout
# All ready got the: 383 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Rear-engine,_four-wheel-drive_layout
# All ready got the: 384 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Engine_configuration
# All ready got the: 385 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Flat_engine
# All ready got the: 386 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Four-stroke_engine
# All ready got the: 387 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/H_engine
# All ready got the: 388 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Reciprocating_engine
# All ready got the: 389 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Single-cylinder_engine
# All ready got the: 390 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Straight_engine
# All ready got the: 391 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Two-stroke_engine
# All ready got the: 392 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/V_engine
# All ready got the: 393 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/W_engine
# All ready got the: 394 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Wankel_engine
# All ready got the: 395 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/List_of_renewable_energy_topics_by_country
# All ready got the: 396 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Renewable_energy_in_Africa
# All ready got the: 397 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Renewable_energy_in_Ethiopia
# All ready got the: 398 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Renewable_energy_in_Kenya
# All ready got the: 399 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Renewable_energy_in_Morocco
# All ready got the: 400 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Renewable_energy_in_Seychelles
# All ready got the: 401 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Renewable_Energy_in_South_Africa
# All ready got the: 402 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Renewable_energy_in_Asia
# All ready got the: 403 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Renewable_energy_in_Afghanistan
# All ready got the: 404 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Renewable_energy_in_Armenia
# All ready got the: 405 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Renewable_energy_in_Bangladesh
# ...
# All ready got the: 878 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Market_share
# All ready got the: 878 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%9308
# All ready got the: 878 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/2010s_oil_glut
# All ready got the: 878 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Market_share
# All ready got the: 878 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Market_share
# All ready got the: 878 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Toyota_Prius_family
# All ready got the: 879 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Market_share
# All ready got the: 879 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Lincoln_MKZ
# All ready got the: 880 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Mercury_Milan
# All ready got the: 881 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/New_York_(state)
# All ready got the: 882 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Florida
# All ready got the: 882 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/United_States_metropolitan_area
# All ready got the: 883 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Greater_Los_Angeles_Area
# All ready got the: 884 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/New_York_metropolitan_area
# All ready got the: 885 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/San_Francisco_Bay_Area
# All ready got the: 886 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Washington_Metropolitan_Area
# All ready got the: 887 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Chicago_metropolitan_area
# All ready got the: 888 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/File:2017_Toyota_Auris_Design_TSS_Hybrid_VVt-i_CVT_2.0_Front.jpg
# All ready got the: 889 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/EU_Member_States
# All ready got the: 890 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Market_share
# All ready got the: 890 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Prius_c
# All ready got the: 891 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Western_Europe
# All ready got the: 892 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/EFTA
# All ready got the: 893 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Honda_Jazz_Hybrid
# All ready got the: 894 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Market_share
# All ready got the: 894 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Financial_crisis_of_2007%E2%80%9308
# All ready got the: 894 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Free-piston_engine
# All ready got the: 895 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Bioethanol
# All ready got the: 896 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Flexible_fuel_engine
# All ready got the: 897 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Diesel-electric
# All ready got the: 898 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Peugeot_307
# All ready got the: 899 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Citro%C3%ABn_C4
# All ready got the: 900 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Citro%C3%ABn_C-Cactus
# All ready got the: 901 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/General_Motors_Corporation
# All ready got the: 902 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Opel_Astra
# All ready got the: 903 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Robert_Bosch_GmbH
# All ready got the: 904 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Peugeot_308
# All ready got the: 905 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Mass_transit
# All ready got the: 906 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/FedEx
# All ready got the: 907 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Eaton_Corporation
# All ready got the: 908 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Iveco
# All ready got the: 909 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Hyundai
# All ready got the: 910 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Hydrogen_fuel_cells
# All ready got the: 911 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Flexifuel_vehicle
# All ready got the: 912 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Flexible-fuel
# All ready got the: 913 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Neat_alcohol_fuel
# All ready got the: 914 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Sweden
# All ready got the: 915 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Flex-fuel
# All ready got the: 916 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Power_inverter
# All ready got the: 917 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Brushless_DC_motor
# All ready got the: 918 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Neodymium_magnet
# All ready got the: 919 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Aftermarket_kit
# All ready got the: 920 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Hybrid_vehicle#Environmental_issues
# All ready got the: 921 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Hybrid_vehicle#Fuel_consumption_and_emissions_reductions
# All ready got the: 922 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Roadway_air_dispersion_modeling
# All ready got the: 923 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Atkinson_cycle
# All ready got the: 924 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Roadway_noise
# All ready got the: 924 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Noise_mitigation
# All ready got the: 925 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Noise_health_effects
# All ready got the: 926 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Ministry_of_Land,_Infrastructure,_Transport_and_Tourism_(Japan)
# All ready got the: 927 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Barack_Obama
# All ready got the: 928 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Plug-in_electric_vehicle
# All ready got the: 928 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Nissan_Leaf#Warning_sounds
# All ready got the: 929 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Infiniti_M#Hybrid_version_(2011–)
# All ready got the: 930 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Fisker_Karma
# All ready got the: 931 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Electric_vehicle_warning_sounds#Toyota
# All ready got the: 932 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Prius_v
# All ready got the: 933 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/After-market_(general)
# All ready got the: 934 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Fuel-cell
# All ready got the: 935 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Hybrid_Scorecard
# All ready got the: 936 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/NiMH
# All ready got the: 937 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/NiCd
# All ready got the: 938 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Green_Car_Journal
# All ready got the: 939 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/U.S._Environmental_Protection_Agency
# All ready got the: 940 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Miles_per_gallon
# All ready got the: 941 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/USD
# All ready got the: 942 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Carbon_Dioxide
# All ready got the: 943 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/United_States_emission_standards#Air_pollution_score
# All ready got the: 944 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Barrel_(unit)#Oil_barrel
# All ready got the: 945 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Toyota_Prius#Third_generation_(ZVW30;_2009–present)
# All ready got the: 946 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Honda_Accord#Ninth_generation_(2013–present)
# All ready got the: 947 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Honda_Civic_Hybrid#Third_generation_(2011-_)
# All ready got the: 948 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Zero_Motorcycles
# All ready got the: 949 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Vectrix
# All ready got the: 950 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/All-electric_motorcycle
# All ready got the: 951 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Scooter_(motorcycle)
# All ready got the: 952 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Electric_motor
# All ready got the: 952 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Stop-start
# All ready got the: 953 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/SEMA
# All ready got the: 954 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Yamaha_Motor_Company
# All ready got the: 955 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Lithium-ion
# All ready got the: 956 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Startup_company
# All ready got the: 957 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Mainstream_market
# All ready got the: 958 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Mercedes_F1_W06_Hybrid
# All ready got the: 959 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Nico_Rosberg
# All ready got the: 960 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/2015_Malaysian_Grand_Prix
# All ready got the: 961 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Audi_R18
# All ready got the: 962 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Porsche_919
# All ready got the: 963 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/24_hours_of_Le_Mans
# All ready got the: 964 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Hybrid_taxi
# All ready got the: 964 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/File:2016_Toyota_Prius_(ZVW50R)_Hybrid_liftback,_SMRT_taxis_(2017-11-29).jpg
# All ready got the: 965 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Singapore
# All ready got the: 965 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Vancouver
# All ready got the: 966 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/British_Columbia
# All ready got the: 966 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Austria
# All ready got the: 967 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/San_Francisco
# All ready got the: 967 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/New_York_City
# All ready got the: 967 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Tokyo
# All ready got the: 968 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Sydney
# All ready got the: 969 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Melbourne
# All ready got the: 970 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Rome
# All ready got the: 971 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Hybrid_electric_bus
# All ready got the: 972 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Hybrid_electric_truck
# All ready got the: 972 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/File:165Hybrid.jpg
# All ready got the: 973 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Hino_Motors
# All ready got the: 974 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Mercedes_Benz
# All ready got the: 975 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Mercedes-Benz_Sprinter
# All ready got the: 976 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Micro-Vett_SPA
# All ready got the: 977 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Navistar_International
# All ready got the: 978 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Eaton_Corp.
# All ready got the: 979 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Isuzu
# All ready got the: 980 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Liebherr_T_282B
# All ready got the: 981 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/LeTourneau_L-2350
# All ready got the: 981 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Wheel_loader
# All ready got the: 981 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/BelAZ
# All ready got the: 982 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/USSR
# All ready got the: 983 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Belarus
# All ready got the: 984 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Crawler-Transporter
# All ready got the: 985 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Mitsubishi_Fuso_Canter_Eco_Hybrid
# All ready got the: 986 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Azure_Dynamics
# All ready got the: 987 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Electric_motor
# All ready got the: 987 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/DAF_Trucks
# All ready got the: 988 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/MAN_Truck_%26_Bus
# All ready got the: 989 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Nissan_Motors
# All ready got the: 990 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Renault_Trucks
# All ready got the: 991 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/ZF_Friedrichshafen
# All ready got the: 992 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/EPower_Engine_Systems
# All ready got the: 992 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Voice_vote
# All ready got the: 993 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/United_States_House_of_Representatives
# All ready got the: 993 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Truck_classification
# All ready got the: 994 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/James_Sensenbrenner
# All ready got the: 995 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Future_Combat_System
# All ready got the: 996 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/United_States_Department_of_Defense
# All ready got the: 997 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Millenworks_Light_Utility_Vehicle
# All ready got the: 998 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/International_FTTS
# All ready got the: 999 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Heavy_Expanded_Mobility_Tactical_Truck
# All ready got the: 1000 URL.  Currently crawling at:  <---  https://en.wikipedia.org/wiki/Hybrid_Locomotive
# We are already get 1000 urls. Stop crawlling now!

# %%
from operator import itemgetter
def writ_in_order(filepath):

    with open(filepath,encoding="utf-8") as fp:  
        lines = fp.readlines()
        lines.sort(key=lambda l: float(l.split()[1]))

    with open('problem2result.txt', 'a+',encoding="utf-8") as outfile: 
        for line in lines:  
            outfile.write(line)
            #print(lines)

        #new_lines = sorted(lines,key=itemgetter(1))

       # cnt = 1
    """
    for line in lines:  
        url,depth = line.split()
        print("{} {}".format(depth, url))
            #print("Line {}: {}".format(cnt, line.strip()))
            #line = fp.readline()
            #cnt += 1 
    
    """

# %% [markdown]
# # Entrance of problem 2

# %%
def problem2(): 
    filenames = ['ElectricCar.txt', 'CarbonFootprint.txt','Timezon.txt']
    with open('merge.txt', 'a+',encoding="utf-8") as outfile:
        for fname in filenames:
            with open(fname,encoding="utf-8") as infile:
                content = infile.read() 
                try:
                    re.compile('\n$').search(content).group()
                    outfile.write(content)
                except AttributeError:
                    content = content +'\n'
                    outfile.write(content)
    filepath = "merge.txt"
    writ_in_order(filepath);
problem2()
